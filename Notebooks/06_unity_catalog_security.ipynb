# %%
# %sql
create or replace function fraud_analytics.bronze.mask_amount(amount DOUBLE) return case 
when is_member('data_engineer') then amount else null end;

# %%
# %sql
alter table fraud_analytics.silver.credit_card_fraud alter column amount set mask fraud_analytics.bronze.mask_amount;

# %%
# %sql
describe extended fraud_analytics.silver.credit_card_fraud;
